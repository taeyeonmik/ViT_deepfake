# %%
print(len(effb1vit_tr_loss), len(effb1vit_vl_loss), len(effb1vit_vl_f1))
# Out:
# 30 30 30

# %%
import matplotlib.pyplot as plt
def plot_loss(train_loss1, train_loss2, train_loss3, valid_loss1, valid_loss2, valid_loss3):
    epochs = range(1, len(train_loss1) + 1)

    # Tracer la courbe des valeurs de perte
    plt.figure(figsize=(10, 6))
    #train
    # plt.plot(epochs, train_loss1, marker='o', markersize=5, linestyle='--', color='k', label='(Train) EffNetB0 (baseline)')
    # plt.plot(epochs, train_loss2, marker='o', markersize=5, linestyle='--', color='b', label='(Train) EffNetB0+ViT')
    # plt.plot(epochs, train_loss3, marker='o', markersize=5, linestyle='--', color='m', label='(Train) EffNetB1+ViT')
    #valid
    plt.plot(epochs, valid_loss1, marker='+', markersize=5, linestyle='-', color='k', label='(Valid) EffNetB0 (baseline)')
    plt.plot(epochs, valid_loss2, marker='+', markersize=5, linestyle='-', color='b', label='(Valid) EffNetB0+ViT')
    plt.plot(epochs, valid_loss3, marker='+', markersize=5, linestyle='-', color='m', label='(Valid) EffNetB1+ViT')

    # Ajouter des étiquettes et un titre
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Comparison for Validation Loss over Epochs')

    # Afficher la légende
    plt.legend()

    # Afficher la grille
    plt.grid(True)

    # Afficher le graphique
    plt.show()

# %%
plot_loss(effb0_tr_loss, effb0vit_tr_loss, effb1vit_tr_loss, effb0_vl_loss, effb0vit_vl_loss, effb1vit_vl_loss)

# %%
plot_loss(effb0_tr_loss, effb0vit_tr_loss, effb1vit_tr_loss, effb0_vl_loss, effb0vit_vl_loss, effb1vit_vl_loss)

# %%
plot_loss(effb0_tr_loss, effb0vit_tr_loss, effb1vit_tr_loss, effb0_vl_loss, effb0vit_vl_loss, effb1vit_vl_loss)

# %%
plot_loss(effb0_tr_loss, effb0vit_tr_loss, effb1vit_tr_loss, effb0_vl_loss, effb0vit_vl_loss, effb1vit_vl_loss)

# %%
#def plot_loss(train_loss1, train_loss2, train_loss3, valid_loss1, valid_loss2, valid_loss3):
def plot_f1(vl_f1_1, vl_f1_2, vl_f1_3):
    epochs = range(1, len(vl_f1_1) + 1)

    # Tracer la courbe des valeurs de perte
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, vl_f1_1, marker='o', markersize=5, linestyle='-', color='k', label='(Valid) EffNetB0 (baseline)')
    plt.plot(epochs, vl_f1_2, marker='o', markersize=5, linestyle='-', color='b', label='(Valid) EffNetB0+ViT')
    plt.plot(epochs, vl_f1_3, marker='o', markersize=5, linestyle='-', color='m', label='(Valid) EffNetB1+ViT')

    # Ajouter des étiquettes et un titre
    plt.xlabel('Epochs')
    plt.ylabel('F1-score')
    plt.title('Validation F1-score over Epochs')

    # Afficher la légende
    plt.legend()

    # Afficher la grille
    plt.grid(True)

    # Afficher le graphique
    plt.show()

# %%
plot_f1(effb0_vl_f1, effb0vit_vl_f1, effb1vit_vl_f1)
